# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Space X  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# ## Web scraping Falcon 9 and Falcon Heavy Launches Records from Wikipedia

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# In this lab, you will be performing web scraping to collect Falcon 9 historical launch records from a Wikipedia page titled `List of Falcon 9 and Falcon Heavy launches`
#
# [https://en.wikipedia.org/wiki/List_of_Falcon\_9\_and_Falcon_Heavy_launches](https://en.wikipedia.org/wiki/List_of_Falcon\_9\_and_Falcon_Heavy_launches?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01)

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_1\_L2/images/Falcon9\_rocket_family.svg)

# %% [markdown]
# Falcon 9 first stage will land successfully

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/landing\_1.gif)

# %% [markdown]
# Several examples of an unsuccessful landing are shown here:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/api/Images/crash.gif)

# %% [markdown]
# More specifically, the launch records are stored in a HTML table shown below:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module\_1\_L2/images/falcon9-launches-wiki.png)

# %% [markdown]
# ## Objectives
#
# Web scrap Falcon 9 launch records with `BeautifulSoup`:
#
# *   Extract a Falcon 9 launch records HTML table from Wikipedia
# *   Parse the table and convert it into a Pandas data frame

# %% [markdown]
# First let's import required packages for this lab

# %%
# !pip3 install beautifulsoup4
# !pip3 install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.28.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.3)

# %%
import sys

import requests
from bs4 import BeautifulSoup
import re
import unicodedata
import pandas as pd

# %% [markdown]
# and we will provide some helper functions for you to process web scraped HTML table

# %%
def date_time(table_cells):
    """
    This function returns the data and time from the HTML  table cell
    Input: the  element of a table data cell extracts extra row
    """
    return [data_time.strip() for data_time in list(table_cells.strings)][0:2]

def booster_version(table_cells):
    """
    This function returns the booster version from the HTML  table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=''.join([booster_version for i,booster_version in enumerate( table_cells.strings) if i%2==0][0:-1])
    return out

def landing_status(table_cells):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    out=[i for i in table_cells.strings][0]
    return out


def get_mass(table_cells):
    mass=unicodedata.normalize("NFKD", table_cells.text).strip()
    if mass:
        mass.find("kg")
        new_mass=mass[0:mass.find("kg")+2]
    else:
        new_mass=0
    return new_mass


def extract_column_from_header(row):
    """
    This function returns the landing status from the HTML table cell 
    Input: the  element of a table data cell extracts extra row
    """
    if (row.br):
        row.br.extract()
    if row.a:
        row.a.extract()
    if row.sup:
        row.sup.extract()
        
    colunm_name = ' '.join(row.contents)
    
    # Filter the digit and empty names
    if not(colunm_name.strip().isdigit()):
        colunm_name = colunm_name.strip()
        return colunm_name

# %% [markdown]
# To keep the lab tasks consistent, you will be asked to scrape the data from a snapshot of the  `List of Falcon 9 and Falcon Heavy launches` Wikipage updated on
# `9th June 2021`

# %%
static_url = "https://en.wikipedia.org/w/index.php?title=List_of_Falcon_9_and_Falcon_Heavy_launches&oldid=1027686922"

# %% [markdown]
# Next, request the HTML page from the above URL and get a `response` object

# %% [markdown]
# ### TASK 1: Request the Falcon9 Launch Wiki page from its URL

# %% [markdown]
# First, let's perform an HTTP GET method to request the Falcon9 Launch HTML page, as an HTTP response.

# %%
# use requests.get() method with the provided static_url
# assign the response to a object
html = requests.get(static_url).text

# %% [markdown]
# Create a `BeautifulSoup` object from the HTML `response`

# %%
# Use BeautifulSoup() to create a BeautifulSoup object from a response text content
soup = BeautifulSoup(html, "html.parser")

# %% [markdown]
# Print the page title to verify if the `BeautifulSoup` object was created properly

# %%
# Use soup.title attribute
print(soup.title)
# Out:
# <title>List of Falcon 9 and Falcon Heavy launches - Wikipedia</title>

# %% [markdown]
# ### TASK 2: Extract all column/variable names from the HTML table header

# %% [markdown]
# Next, we want to collect all relevant column names from the HTML table header

# %% [markdown]
# Let's try to find all tables on the wiki page first. If you need to refresh your memory about `BeautifulSoup`, please check the external reference link towards the end of this lab

# %%
# Use the find_all function in the BeautifulSoup object, with element type `table`
# Assign the result to a list called `html_tables`
html_tables = soup.find_all('tbody')

# %% [markdown]
# Starting from the third table is our target table contains the actual launch records.

# %%
# Let's print the third table and check its content
first_launch_table = html_tables[2]
#print(first_launch_table)

# %% [markdown]
# You should able to see the columns names embedded in the table header elements `<th>` as follows:

# %% [markdown]
# ```
# <tr>
# <th scope="col">Flight No.
# </th>
# <th scope="col">Date and<br/>time (<a href="/wiki/Coordinated_Universal_Time" title="Coordinated Universal Time">UTC</a>)
# </th>
# <th scope="col"><a href="/wiki/List_of_Falcon_9_first-stage_boosters" title="List of Falcon 9 first-stage boosters">Version,<br/>Booster</a> <sup class="reference" id="cite_ref-booster_11-0"><a href="#cite_note-booster-11">[b]</a></sup>
# </th>
# <th scope="col">Launch site
# </th>
# <th scope="col">Payload<sup class="reference" id="cite_ref-Dragon_12-0"><a href="#cite_note-Dragon-12">[c]</a></sup>
# </th>
# <th scope="col">Payload mass
# </th>
# <th scope="col">Orbit
# </th>
# <th scope="col">Customer
# </th>
# <th scope="col">Launch<br/>outcome
# </th>
# <th scope="col"><a href="/wiki/Falcon_9_first-stage_landing_tests" title="Falcon 9 first-stage landing tests">Booster<br/>landing</a>
# </th></tr>
# ```

# %% [markdown]
# Next, we just need to iterate through the `<th>` elements and apply the provided `extract_column_from_header()` to extract column name one by one

# %%
column_names = []

# Apply find_all() function with `th` element on first_launch_table
# Iterate each th element and apply the provided extract_column_from_header() to get a column name
# Append the Non-empty column name (`if name is not None and len(name) > 0`) into a list called column_names
for th in first_launch_table.find_all('th'):
    name = extract_column_from_header(th)
    if name is not None and len(name) > 0:
        column_names.append(name)

# %% [markdown]
# Check the extracted column names

# %%
print(column_names)
# Out:
# ['Flight No.', 'Date and time ( )', 'Launch site', 'Payload', 'Payload mass', 'Orbit', 'Customer', 'Launch outcome']

# %% [markdown]
# ## TASK 3: Create a data frame by parsing the launch HTML tables

# %% [markdown]
# We will create an empty dictionary with keys from the extracted column names in the previous task. Later, this dictionary will be converted into a Pandas dataframe

# %%
launch_dict= dict.fromkeys(column_names)

# Remove an irrelvant column
del launch_dict['Date and time ( )']

# Let's initial the launch_dict with each value to be an empty list
for i in launch_dict:
    launch_dict[i]=[]
# Added some new columns
launch_dict['Version Booster']=[]
launch_dict['Booster landing']=[]
launch_dict['Date']=[]
launch_dict['Time']=[]

# %% [markdown]
# Next, we just need to fill up the `launch_dict` with launch records extracted from table rows.

# %% [markdown]
# Usually, HTML tables in Wiki pages are likely to contain unexpected annotations and other types of noises, such as reference links `B0004.1[8]`, missing values `N/A [e]`, inconsistent formatting, etc.

# %% [markdown]
# To simplify the parsing process, we have provided an incomplete code snippet below to help you to fill up the `launch_dict`. Please complete the following code snippet with TODOs or you can choose to write your own logic to parse all launch tables:

# %%
count_tables = 0
count_rows = 0
count_th = 0
count_th_string = 0
extract_row = 0

#Extract each table 
for table_number,table in enumerate(soup.find_all('table',"wikitable plainrowheaders collapsible")):   
    count_tables += 1
    # get table row 
    for rows in table.find_all("tr"):
        count_rows += 1
        #check to see if first table heading is as number corresponding to launch a number 
        if rows.th:
            count_th += 1
            if rows.th.string:
                count_th_string += 1
                flight_number=rows.th.string.strip()
                flag=flight_number.isdigit()
        else:
            flag=False
        #get table element 
        row=rows.find_all('td')
        #if it is number save cells in a dictonary 
        if flag:
            extract_row += 1
            # Flight Number value
            # TODO: Append the flight_number into launch_dict with key `Flight No.`
            launch_dict['Flight No.'].append(flight_number)
            print(flight_number, 'flight_number')
            
            datatimelist=date_time(row[0])
            
            # Date value
            # TODO: Append the date into launch_dict with key `Date`
            date = datatimelist[0].strip(',')
            launch_dict['Date'].append(date)
            print(date, 'date')
            
            # Time value
            # TODO: Append the time into launch_dict with key `Time`
            time = datatimelist[1]
            launch_dict['Time'].append(time)
            print(time, 'time')
              
            # Booster version
            # TODO: Append the bv into launch_dict with key `Version Booster`
            bv=booster_version(row[1])
            if not(bv):
                bv=row[1].a.string
            launch_dict['Version Booster'].append(bv)
            print(bv, 'booster version')
            
            # Launch Site
            # TODO: Append the bv(sic! shure it is wrong) into launch_dict with key `Launch Site`
            launch_site = row[2].a.string
            launch_dict['Launch site'].append(launch_site)
            print(launch_site, 'launch_site')
            
            # Payload
            # TODO: Append the payload into launch_dict with key `Payload`
            payload = row[3].a.string
            launch_dict['Payload'].append(payload)
            print(payload, 'payload')
            
            # Payload Mass
            # TODO: Append the payload_mass into launch_dict with key `Payload mass`
            payload_mass = get_mass(row[4])
            launch_dict['Payload mass'].append(payload_mass)
            print(payload_mass, 'payload_mass')
            
            # Orbit
            # TODO: Append the orbit into launch_dict with key `Orbit`
            orbit = row[5].a.string
            launch_dict['Orbit'].append(orbit)
            print(orbit, 'orbit')
            
            # Customer
            # TODO: Append the customer into launch_dict with key `Customer`
            try:
                customer = row[6].a.string
            except:
                customer = row[6].string.strip()
            launch_dict['Customer'].append(customer)
            print(customer, 'customer')
            
            # Launch outcome
            # TODO: Append the launch_outcome into launch_dict with key `Launch outcome`
            launch_outcome = list(row[7].strings)[0].strip()
            launch_dict['Launch outcome'].append(launch_outcome)
            print(launch_outcome, 'launch_outcome')
            
            # Booster landing
            # TODO: Append the launch_outcome into launch_dict with key `Booster landing`
            booster_landing = landing_status(row[8]).strip()
            launch_dict['Booster landing'].append(booster_landing)
            print(booster_landing, 'booster_landing')
# Out:
# 1 flight_number
# 4 June 2010 date
# 18:45 time
# F9 v1.0B0003.1 booster version
# CCAFS launch_site
# Dragon Spacecraft Qualification Unit payload
# 0 payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Failure booster_landing
# 2 flight_number
# 8 December 2010 date
# 15:43 time
# F9 v1.0B0004.1 booster version
# CCAFS launch_site
# Dragon payload
# 0 payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Failure booster_landing
# 3 flight_number
# 22 May 2012 date
# 07:44 time
# F9 v1.0B0005.1 booster version
# CCAFS launch_site
# Dragon payload
# 525 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# No attempt booster_landing
# 4 flight_number
# 8 October 2012 date
# 00:35 time
# F9 v1.0B0006.1 booster version
# CCAFS launch_site
# SpaceX CRS-1 payload
# 4,700 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# No attempt booster_landing
# 5 flight_number
# 1 March 2013 date
# 15:10 time
# F9 v1.0B0007.1 booster version
# CCAFS launch_site
# SpaceX CRS-2 payload
# 4,877 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# No attempt booster_landing
# 6 flight_number
# 29 September 2013 date
# 16:00 time
# F9 v1.1B1003 booster version
# VAFB launch_site
# CASSIOPE payload
# 500 kg payload_mass
# Polar orbit orbit
# MDA customer
# Success launch_outcome
# Uncontrolled booster_landing
# 7 flight_number
# 3 December 2013 date
# 22:41 time
# F9 v1.1 booster version
# CCAFS launch_site
# SES-8 payload
# 3,170 kg payload_mass
# GTO orbit
# SES customer
# Success launch_outcome
# No attempt booster_landing
# 8 flight_number
# 6 January 2014 date
# 22:06 time
# F9 v1.1 booster version
# CCAFS launch_site
# Thaicom 6 payload
# 3,325 kg payload_mass
# GTO orbit
# Thaicom customer
# Success launch_outcome
# No attempt booster_landing
# 9 flight_number
# 18 April 2014 date
# 19:25 time
# F9 v1.1 booster version
# Cape Canaveral launch_site
# SpaceX CRS-3 payload
# 2,296 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Controlled booster_landing
# 10 flight_number
# 14 July 2014 date
# 15:15 time
# F9 v1.1 booster version
# Cape Canaveral launch_site
# Orbcomm-OG2 payload
# 1,316 kg payload_mass
# LEO orbit
# Orbcomm customer
# Success launch_outcome
# Controlled booster_landing
# 11 flight_number
# 5 August 2014 date
# 08:00 time
# F9 v1.1 booster version
# Cape Canaveral launch_site
# AsiaSat 8 payload
# 4,535 kg payload_mass
# GTO orbit
# AsiaSat customer
# Success launch_outcome
# No attempt booster_landing
# 12 flight_number
# 7 September 2014 date
# 05:00 time
# F9 v1.1 booster version
# Cape Canaveral launch_site
# AsiaSat 6 payload
# 4,428 kg payload_mass
# GTO orbit
# AsiaSat customer
# Success launch_outcome
# No attempt booster_landing
# 13 flight_number
# 21 September 2014 date
# 05:52 time
# F9 v1.1 booster version
# Cape Canaveral launch_site
# SpaceX CRS-4 payload
# 2,216 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Uncontrolled booster_landing
# 14 flight_number
# 10 January 2015 date
# 09:47 time
# F9 v1.1 booster version
# Cape Canaveral launch_site
# SpaceX CRS-5 payload
# 2,395 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Failure booster_landing
# 15 flight_number
# 11 February 2015 date
# 23:03 time
# F9 v1.1 booster version
# Cape Canaveral launch_site
# DSCOVR payload
# 570 kg payload_mass
# HEO orbit
# USAF customer
# Success launch_outcome
# Controlled booster_landing
# 16 flight_number
# 2 March 2015 date
# 03:50 time
# F9 v1.1 booster version
# Cape Canaveral launch_site
# ABS-3A payload
# 4,159 kg payload_mass
# GTO orbit
# ABS customer
# Success launch_outcome
# No attempt booster_landing
# 17 flight_number
# 14 April 2015 date
# 20:10 time
# F9 v1.1 booster version
# Cape Canaveral launch_site
# SpaceX CRS-6 payload
# 1,898 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Failure booster_landing
# 18 flight_number
# 27 April 2015 date
# 23:03 time
# F9 v1.1 booster version
# Cape Canaveral launch_site
# TürkmenÄlem 52°E / MonacoSAT payload
# 4,707 kg payload_mass
# GTO orbit
# None customer
# Success launch_outcome
# No attempt booster_landing
# 19 flight_number
# 28 June 2015 date
# 14:21 time
# F9 v1.1 booster version
# Cape Canaveral launch_site
# SpaceX CRS-7 payload
# 1,952 kg payload_mass
# LEO orbit
# NASA customer
# Failure launch_outcome
# Precluded booster_landing
# 20 flight_number
# 22 December 2015 date
# 01:29 time
# F9 FT booster version
# Cape Canaveral launch_site
# Orbcomm-OG2 payload
# 2,034 kg payload_mass
# LEO orbit
# Orbcomm customer
# Success launch_outcome
# Success booster_landing
# 21 flight_number
# 17 January 2016 date
# 18:42 time
# F9 v1.1 booster version
# VAFB launch_site
# Jason-3 payload
# 553 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Failure booster_landing
# 22 flight_number
# 4 March 2016 date
# 23:35 time
# F9 FT booster version
# Cape Canaveral launch_site
# SES-9 payload
# 5,271 kg payload_mass
# GTO orbit
# SES customer
# Success launch_outcome
# Failure booster_landing
# 23 flight_number
# 8 April 2016 date
# 20:43 time
# F9 FT booster version
# Cape Canaveral launch_site
# SpaceX CRS-8 payload
# 3,136 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 24 flight_number
# 6 May 2016 date
# 05:21 time
# F9 FT booster version
# Cape Canaveral launch_site
# JCSAT-14 payload
# 4,696 kg payload_mass
# GTO orbit
# SKY Perfect JSAT Group customer
# Success launch_outcome
# Success booster_landing
# 25 flight_number
# 27 May 2016 date
# 21:39 time
# F9 FT booster version
# Cape Canaveral launch_site
# Thaicom 8 payload
# 3,100 kg payload_mass
# GTO orbit
# Thaicom customer
# Success launch_outcome
# Success booster_landing
# 26 flight_number
# 15 June 2016 date
# 14:29 time
# F9 FT booster version
# Cape Canaveral launch_site
# ABS-2A payload
# 3,600 kg payload_mass
# GTO orbit
# ABS customer
# Success launch_outcome
# Failure booster_landing
# 27 flight_number
# 18 July 2016 date
# 04:45 time
# F9 FT booster version
# Cape Canaveral launch_site
# SpaceX CRS-9 payload
# 2,257 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 28 flight_number
# 14 August 2016 date
# 05:26 time
# F9 FT booster version
# Cape Canaveral launch_site
# JCSAT-16 payload
# 4,600 kg payload_mass
# GTO orbit
# SKY Perfect JSAT Group customer
# Success launch_outcome
# Success booster_landing
# 29 flight_number
# 14 January 2017 date
# 17:54 time
# F9 FT booster version
# VAFB launch_site
# Iridium NEXT payload
# 9,600 kg payload_mass
# Polar orbit
# Iridium Communications customer
# Success launch_outcome
# Success booster_landing
# 30 flight_number
# 19 February 2017 date
# 14:39 time
# F9 FT booster version
# KSC launch_site
# SpaceX CRS-10 payload
# 2,490 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 31 flight_number
# 16 March 2017 date
# 06:00 time
# F9 FT booster version
# KSC launch_site
# EchoStar 23 payload
# 5,600 kg payload_mass
# GTO orbit
# EchoStar customer
# Success launch_outcome
# No attempt booster_landing
# 32 flight_number
# 30 March 2017 date
# 22:27 time
# F9 FT♺ booster version
# KSC launch_site
# SES-10 payload
# 5,300 kg payload_mass
# GTO orbit
# SES customer
# Success launch_outcome
# Success booster_landing
# 33 flight_number
# 1 May 2017 date
# 11:15 time
# F9 FT booster version
# KSC launch_site
# NROL-76 payload
# C payload_mass
# LEO orbit
# NRO customer
# Success launch_outcome
# Success booster_landing
# 34 flight_number
# 15 May 2017 date
# 23:21 time
# F9 FT booster version
# KSC launch_site
# Inmarsat-5 F4 payload
# 6,070 kg payload_mass
# GTO orbit
# Inmarsat customer
# Success launch_outcome
# No attempt booster_landing
# 35 flight_number
# 3 June 2017 date
# 21:07 time
# F9 FT booster version
# KSC launch_site
# SpaceX CRS-11 payload
# 2,708 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 36 flight_number
# 23 June 2017 date
# 19:10 time
# F9 FTB1029.2 booster version
# KSC launch_site
# BulgariaSat-1 payload
# 3,669 kg payload_mass
# GTO orbit
# Bulsatcom customer
# Success launch_outcome
# Success booster_landing
# 37 flight_number
# 25 June 2017 date
# 20:25 time
# F9 FT booster version
# VAFB launch_site
# Iridium NEXT payload
# 9,600 kg payload_mass
# LEO orbit
# Iridium Communications customer
# Success launch_outcome
# Success booster_landing
# 38 flight_number
# 5 July 2017 date
# 23:38 time
# F9 FT booster version
# KSC launch_site
# Intelsat 35e payload
# 6,761 kg payload_mass
# GTO orbit
# Intelsat customer
# Success launch_outcome
# No attempt booster_landing
# 39 flight_number
# 14 August 2017 date
# 16:31 time
# F9 B4 booster version
# KSC launch_site
# SpaceX CRS-12 payload
# 3,310 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 40 flight_number
# 24 August 2017 date
# 18:51 time
# F9 FT booster version
# VAFB launch_site
# Formosat-5 payload
# 475 kg payload_mass
# SSO orbit
# NSPO customer
# Success launch_outcome
# Success booster_landing
# 41 flight_number
# 7 September 2017 date
# 14:00 time
# F9 B4 booster version
# KSC launch_site
# Boeing X-37B payload
# 4,990 kg payload_mass
# LEO orbit
# USAF customer
# Success launch_outcome
# Success booster_landing
# 42 flight_number
# 9 October 2017 date
# 12:37 time
# F9 B4 booster version
# VAFB launch_site
# Iridium NEXT payload
# 9,600 kg payload_mass
# Polar orbit
# Iridium Communications customer
# Success launch_outcome
# Success booster_landing
# 43 flight_number
# 11 October 2017 date
# 22:53:00 time
# F9 FTB1031.2 booster version
# KSC launch_site
# SES-11 payload
# 5,200 kg payload_mass
# GTO orbit
# SES S.A. customer
# Success launch_outcome
# Success booster_landing
# 44 flight_number
# 30 October 2017 date
# 19:34 time
# F9 B4 booster version
# KSC launch_site
# Koreasat 5A payload
# 3,500 kg payload_mass
# GTO orbit
# KT Corporation customer
# Success launch_outcome
# Success booster_landing
# 45 flight_number
# 15 December 2017 date
# 15:36 time
# F9 FTB1035.2 booster version
# Cape Canaveral launch_site
# SpaceX CRS-13 payload
# 2,205 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 46 flight_number
# 23 December 2017 date
# 01:27 time
# F9 FTB1036.2 booster version
# VAFB launch_site
# Iridium NEXT payload
# 9,600 kg payload_mass
# Polar orbit
# Iridium Communications customer
# Success launch_outcome
# Controlled booster_landing
# 47 flight_number
# 8 January 2018 date
# 01:00 time
# F9 B4 booster version
# CCAFS launch_site
# Zuma payload
# C payload_mass
# LEO orbit
# Northrop Grumman customer
# Success launch_outcome
# Success booster_landing
# 48 flight_number
# 31 January 2018 date
# 21:25 time
# F9 FTB1032.2 booster version
# CCAFS launch_site
# GovSat-1 payload
# 4,230 kg payload_mass
# GTO orbit
# SES customer
# Success launch_outcome
# Controlled booster_landing
# 49 flight_number
# 22 February 2018 date
# 14:17 time
# F9 FTB1038.2 booster version
# VAFB launch_site
# Paz payload
# 2,150 kg payload_mass
# SSO orbit
# Hisdesat customer
# Success launch_outcome
# No attempt booster_landing
# 50 flight_number
# 6 March 2018 date
# 05:33 time
# F9 B4 booster version
# CCAFS launch_site
# Hispasat 30W-6 payload
# 6,092 kg payload_mass
# GTO orbit
# Hispasat customer
# Success launch_outcome
# No attempt booster_landing
# 51 flight_number
# 30 March 2018 date
# 14:14 time
# F9 B4B1041.2 booster version
# VAFB launch_site
# Iridium NEXT payload
# 9,600 kg payload_mass
# Polar orbit
# Iridium Communications customer
# Success launch_outcome
# No attempt booster_landing
# 52 flight_number
# 2 April 2018 date
# 20:30 time
# F9 B4B1039.2 booster version
# CCAFS launch_site
# SpaceX CRS-14 payload
# 2,647 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# No attempt booster_landing
# 53 flight_number
# 18 April 2018 date
# 22:51 time
# F9 B4 booster version
# CCAFS launch_site
# Transiting Exoplanet Survey Satellite payload
# 362 kg payload_mass
# HEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 54 flight_number
# 11 May 2018 date
# 20:14 time
# F9 B5B1046.1 booster version
# KSC launch_site
# Bangabandhu-1 payload
# 3,600 kg payload_mass
# GTO orbit
# Thales-Alenia customer
# Success launch_outcome
# Success booster_landing
# 55 flight_number
# 22 May 2018 date
# 19:47 time
# F9 B4B1043.2 booster version
# VAFB launch_site
# Iridium NEXT payload
# 6,460 kg payload_mass
# Polar orbit
# Iridium Communications customer
# Success launch_outcome
# No attempt booster_landing
# 56 flight_number
# 4 June 2018 date
# 04:45 time
# F9 B4B1040.2 booster version
# CCAFS launch_site
# SES-12 payload
# 5,384 kg payload_mass
# GTO orbit
# SES customer
# Success launch_outcome
# No attempt booster_landing
# 57 flight_number
# 29 June 2018 date
# 09:42 time
# F9 B4B1045.2 booster version
# CCAFS launch_site
# SpaceX CRS-15 payload
# 2,697 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# No attempt booster_landing
# 58 flight_number
# 22 July 2018 date
# 05:50 time
# F9 B5 booster version
# CCAFS launch_site
# Telstar 19V payload
# 7,075 kg payload_mass
# GTO orbit
# Telesat customer
# Success launch_outcome
# Success booster_landing
# 59 flight_number
# 25 July 2018 date
# 11:39 time
# F9 B5B1048 booster version
# VAFB launch_site
# Iridium NEXT payload
# 9,600 kg payload_mass
# Polar orbit
# Iridium Communications customer
# Success launch_outcome
# Success booster_landing
# 60 flight_number
# 7 August 2018 date
# 05:18 time
# F9 B5B1046.2 booster version
# CCAFS launch_site
# Merah Putih payload
# 5,800 kg payload_mass
# GTO orbit
# Telkom Indonesia customer
# Success launch_outcome
# Success booster_landing
# 61 flight_number
# 10 September 2018 date
# 04:45 time
# F9 B5 booster version
# CCAFS launch_site
# Telstar 18V payload
# 7,060 kg payload_mass
# GTO orbit
# Telesat customer
# Success launch_outcome
# Success booster_landing
# 62 flight_number
# 8 October 2018 date
# 02:22 time
# F9 B5B1048.2 booster version
# VAFB launch_site
# SAOCOM 1A payload
# 3,000 kg payload_mass
# SSO orbit
# CONAE customer
# Success launch_outcome
# Success booster_landing
# 63 flight_number
# 15 November 2018 date
# 20:46 time
# F9 B5B1047.2 booster version
# KSC launch_site
# Es'hail 2 payload
# 5,300 kg payload_mass
# GTO orbit
# Es'hailSat customer
# Success launch_outcome
# Success booster_landing
# 64 flight_number
# 3 December 2018 date
# 18:34:05 time
# F9 B5B1046.3 booster version
# VAFB launch_site
# SSO-A payload
# ~4,000 kg payload_mass
# SSO orbit
# Spaceflight Industries customer
# Success launch_outcome
# Success booster_landing
# 65 flight_number
# 5 December 2018 date
# 18:16 time
# F9 B5 booster version
# CCAFS launch_site
# SpaceX CRS-16 payload
# 2,500 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Failure booster_landing
# 66 flight_number
# 23 December 2018 date
# 13:51 time
# F9 B5 booster version
# CCAFS launch_site
# GPS III payload
# 4,400 kg payload_mass
# MEO orbit
# USAF customer
# Success launch_outcome
# No attempt booster_landing
# 67 flight_number
# 11 January 2019 date
# 15:31 time
# F9 B5B1049.2 booster version
# VAFB launch_site
# Iridium NEXT payload
# 9,600 kg payload_mass
# Polar orbit
# Iridium Communications customer
# Success launch_outcome
# Success booster_landing
# 68 flight_number
# 22 February 2019 date
# 01:45 time
# F9 B5B1048.3 booster version
# CCAFS launch_site
# Nusantara Satu payload
# 4,850 kg payload_mass
# GTO orbit
# PSN customer
# Success launch_outcome
# Success booster_landing
# 69 flight_number
# 2 March 2019 date
# 07:49 time
# F9 B5[268] booster version
# KSC launch_site
# Crew Dragon Demo-1 payload
# 12,055 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 70 flight_number
# 4 May 2019 date
# 06:48 time
# F9 B5 booster version
# CCAFS launch_site
# SpaceX CRS-17 payload
# 2,495 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 71 flight_number
# 24 May 2019 date
# 02:30 time
# F9 B5B1049.3 booster version
# CCAFS launch_site
# Starlink payload
# 13,620 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 72 flight_number
# 12 June 2019 date
# 14:17 time
# F9 B5B1051.2 booster version
# VAFB launch_site
# RADARSAT Constellation payload
# 4,200 kg payload_mass
# SSO orbit
# Canadian Space Agency customer
# Success launch_outcome
# Success booster_landing
# 73 flight_number
# 25 July 2019 date
# 22:01 time
# F9 B5B1056.2 booster version
# CCAFS launch_site
# SpaceX CRS-18 payload
# 2,268 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 74 flight_number
# 6 August 2019 date
# 23:23 time
# F9 B5B1047.3 booster version
# CCAFS launch_site
# AMOS-17 payload
# 6,500 kg payload_mass
# GTO orbit
# Spacecom customer
# Success launch_outcome
# No attempt booster_landing
# 75 flight_number
# 11 November 2019 date
# 14:56 time
# F9 B5 booster version
# CCAFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 76 flight_number
# 5 December 2019 date
# 17:29 time
# F9 B5 booster version
# CCAFS launch_site
# SpaceX CRS-19 payload
# 2,617 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 77 flight_number
# 17 December 2019 date
# 00:10 time
# F9 B5B1056.3 booster version
# CCAFS launch_site
# JCSat-18 payload
# 6,956 kg payload_mass
# GTO orbit
# Sky Perfect JSAT customer
# Success launch_outcome
# Success booster_landing
# 78 flight_number
# 7 January 2020 date
# 02:19:21 time
# F9 B5 booster version
# CCAFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 79 flight_number
# 19 January 2020 date
# 15:30 time
# F9 B5 booster version
# KSC launch_site
# Crew Dragon in-flight abort test payload
# 12,050 kg payload_mass
# Sub-orbital orbit
# NASA customer
# Success launch_outcome
# No attempt booster_landing
# 80 flight_number
# 29 January 2020 date
# 14:07 time
# F9 B5 booster version
# CCAFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 81 flight_number
# 17 February 2020 date
# 15:05 time
# F9 B5 booster version
# CCAFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Failure booster_landing
# 82 flight_number
# 7 March 2020 date
# 04:50 time
# F9 B5 booster version
# CCAFS launch_site
# SpaceX CRS-20 payload
# 1,977 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 83 flight_number
# 18 March 2020 date
# 12:16 time
# F9 B5 booster version
# KSC launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Failure booster_landing
# 84 flight_number
# 22 April 2020 date
# 19:30 time
# F9 B5 booster version
# KSC launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 85 flight_number
# 30 May 2020 date
# 19:22 time
# F9 B5 booster version
# KSC launch_site
# Crew Dragon Demo-2 payload
# 12,530 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 86 flight_number
# 4 June 2020 date
# 01:25 time
# F9 B5 booster version
# CCAFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 87 flight_number
# 13 June 2020 date
# 09:21 time
# F9 B5 booster version
# CCAFS launch_site
# Starlink payload
# 15,410 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 88 flight_number
# 30 June 2020 date
# 20:10:46 time
# F9 B5 booster version
# CCAFS launch_site
# GPS III payload
# 4,311 kg payload_mass
# MEO orbit
# U.S. Space Force customer
# Success launch_outcome
# Success booster_landing
# 89 flight_number
# 20 July 2020 date
# 21:30 time
# F9 B5B1058.2 booster version
# CCAFS launch_site
# ANASIS-II payload
# 5,000–6,000 kg payload_mass
# GTO orbit
# Republic of Korea Army customer
# Success launch_outcome
# Success booster_landing
# 90 flight_number
# 7 August 2020 date
# 05:12 time
# F9 B5 booster version
# KSC launch_site
# Starlink payload
# 14,932 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 91 flight_number
# 18 August 2020 date
# 14:31 time
# F9 B5B1049.6 booster version
# CCAFS launch_site
# Starlink payload
# ~15,440 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 92 flight_number
# 30 August 2020 date
# 23:18 time
# F9 B5 booster version
# CCAFS launch_site
# SAOCOM 1B payload
# 3,130 kg payload_mass
# SSO orbit
# CONAE customer
# Success launch_outcome
# Success booster_landing
# 93 flight_number
# 3 September 2020 date
# 12:46:14 time
# F9 B5B1060.2 booster version
# KSC launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 94 flight_number
# 6 October 2020 date
# 11:29:34 time
# F9 B5B1058.3 booster version
# KSC launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 95 flight_number
# 18 October 2020 date
# 12:25:57 time
# F9 B5B1051.6 booster version
# KSC launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 96 flight_number
# 24 October 2020 date
# 15:31:34 time
# F9 B5 booster version
# CCAFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 97 flight_number
# 5 November 2020 date
# 23:24:23 time
# F9 B5 booster version
# CCAFS launch_site
# GPS III payload
# 4,311 kg payload_mass
# MEO orbit
# USSF customer
# Success launch_outcome
# Success booster_landing
# 98 flight_number
# 16 November 2020 date
# 00:27 time
# F9 B5 booster version
# KSC launch_site
# Crew-1 payload
# ~12,500 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 99 flight_number
# 21 November 2020 date
# 17:17:08 time
# F9 B5 booster version
# VAFB launch_site
# Sentinel-6 Michael Freilich (Jason-CS A) payload
# 1,192 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 100 flight_number
# 25 November 2020 date
# 02:13 time
# F9 B5 ♺ booster version
# CCAFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 101 flight_number
# 6 December 2020 date
# 16:17:08 time
# F9 B5 ♺ booster version
# KSC launch_site
# SpaceX CRS-21 payload
# 2,972 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 102 flight_number
# 13 December 2020 date
# 17:30:00 time
# F9 B5 ♺ booster version
# CCSFS launch_site
# SXM-7 payload
# 7,000 kg payload_mass
# GTO orbit
# Sirius XM customer
# Success launch_outcome
# Success booster_landing
# 103 flight_number
# 19 December 2020 date
# 14:00:00 time
# F9 B5 ♺ booster version
# KSC launch_site
# NROL-108 payload
# C payload_mass
# LEO orbit
# NRO customer
# Success launch_outcome
# Success booster_landing
# 104 flight_number
# 8 January 2021 date
# 02:15 time
# F9 B5 booster version
# CCSFS launch_site
# Türksat 5A payload
# 3,500 kg payload_mass
# GTO orbit
# Türksat customer
# Success launch_outcome
# Success booster_landing
# 105 flight_number
# 20 January 2021 date
# 13:02 time
# F9 B5B1051.8 booster version
# KSC launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 106 flight_number
# 24 January 2021 date
# 15:00 time
# F9 B5B1058.5 booster version
# CCSFS launch_site
# Transporter-1 payload
# ~5,000 kg payload_mass
# SSO orbit
# Various customer
# Success launch_outcome
# Success booster_landing
# 107 flight_number
# 4 February 2021 date
# 06:19 time
# F9 B5 ♺ booster version
# CCSFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 108 flight_number
# 16 February 2021 date
# 03:59:37 time
# F9 B5 ♺ booster version
# CCSFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Failure booster_landing
# 109 flight_number
# 4 March 2021 date
# 08:24 time
# F9 B5 ♺ booster version
# KSC launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 110 flight_number
# 11 March 2021 date
# 08:13:29 time
# F9 B5 ♺ booster version
# CCSFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 111 flight_number
# 14 March 2021 date
# 10:01 time
# F9 B5 ♺ booster version
# KSC launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 112 flight_number
# 24 March 2021 date
# 08:28 time
# F9 B5B1060.6 booster version
# CCSFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 113 flight_number
# 7 April 2021 date
# 16:34 time
# F9 B5 ♺ booster version
# CCSFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 114 flight_number
# 23 April 2021 date
# 9:49 time
# F9 B5B1061.2 booster version
# KSC launch_site
# Crew-2 payload
# ~13,000 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 115 flight_number
# 29 April 2021 date
# 03:44 time
# F9 B5B1060.7 booster version
# CCSFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 116 flight_number
# 4 May 2021 date
# 19:01 time
# F9 B5B1049.9 booster version
# KSC launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 117 flight_number
# 9 May 2021 date
# 06:42 time
# F9 B5B1051.10 booster version
# CCSFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 118 flight_number
# 15 May 2021 date
# 22:56 time
# F9 B5B1058.8 booster version
# KSC launch_site
# Starlink payload
# ~14,000 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 119 flight_number
# 26 May 2021 date
# 18:59 time
# F9 B5B1063.2 booster version
# CCSFS launch_site
# Starlink payload
# 15,600 kg payload_mass
# LEO orbit
# SpaceX customer
# Success launch_outcome
# Success booster_landing
# 120 flight_number
# 3 June 2021 date
# 17:29 time
# F9 B5B1067.1 booster version
# KSC launch_site
# SpaceX CRS-22 payload
# 3,328 kg payload_mass
# LEO orbit
# NASA customer
# Success launch_outcome
# Success booster_landing
# 121 flight_number
# 6 June 2021 date
# 04:26 time
# F9 B5 booster version
# CCSFS launch_site
# SXM-8 payload
# 7,000 kg payload_mass
# GTO orbit
# Sirius XM customer
# Success launch_outcome
# Success booster_landing

# %% [markdown]
# After you have fill in the parsed launch record values into `launch_dict`, you can create a dataframe from it.

# %%
df=pd.DataFrame(launch_dict)

# %%
df.to_csv('spacex_web_scraped.csv', index=False)

# %% [markdown]
# We can now export it to a <b>CSV</b> for the next section, but to make the answers consistent and in case you have difficulties finishing this lab.
#
# Following labs will be using a provided dataset to make each lab independent.

# %% [markdown]
# <code>df.to_csv('spacex_web_scraped.csv', index=False)</code>

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">Yan Luo</a>

# %% [markdown]
# <a href="https://www.linkedin.com/in/nayefaboutayoun/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork26802033-2022-01-01">Nayef Abou Tayoun</a>

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description          |
# | ----------------- | ------- | ---------- | --------------------------- |
# | 2021-06-09        | 1.0     | Yan Luo    | Tasks updates               |
# | 2020-11-10        | 1.0     | Nayef      | Created the initial version |

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
